# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1_utx_ZGclmCwNttSe40kYA6VHzNocdET' height="60"></center>
#
# AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Program Operacyjny Polska Cyfrowa na lata 2014-2020
# <hr>
#
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# # TL;DR
#
# 1. In this lab scenario you will have a chance to compare performance of the classic RNN and LSTM on a toy example.
# 2. This toy example will show that maintaining memory over even 20 steps is non-trivial.
# 3. Finally, you will see how curriculum learning may allow to train a model on larger sequences.
#
# # Problem definition
#
# Here we consider a toy example, where the goal is to discriminate between two types of binary sequences:
# * [Type 0] a sequence with exactly one zero (remaining entries are equal to one).
# * [Type 1] a sequence full of ones,
#
# We are especially interested in the performance of the trained models on discriminating between a sequence full of ones versus a sequence with leading zero followed by ones. Note that in this case the goal of the model is to output the first element of the sequence, as the label (sequence type) is fully determined by the first element of the sequence.

# %% [markdown]
# #Implementation

# %% [markdown]
# ## Importing torch
#
# Install `torch` and `torchvision`

# %%
# !pip3 install torch torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.13.0+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (0.14.0+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (4.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision) (2.25.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (2022.12.7)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

torch.manual_seed(1)

# %% [markdown]
# ## Understand dimensionality
#
# Check the input and output specification [LSTM](https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html) and [RNN](https://pytorch.org/docs/stable/generated/torch.nn.RNN.html). The following snippet shows how we can process
# a sequence by LSTM and output a vector of size `hidden_dim` after reading
# each token of the sequence.

# %%
hidden_dim = 5
lstm = nn.LSTM(1, hidden_dim)  # Input sequence contains elements - vectors of size 1

# create a random sequence
sequence = [torch.randn(1) for _ in range(10)]

# initialize the hidden state (including cell state)
hidden = (torch.zeros(1, 1, 5),
          torch.zeros(1, 1, 5))

for i, elem in enumerate(sequence):
  # we are processing only a single element of the sequence, and there
  # is only one sample (sequence) in the batch, the third one
  # corresponds to the fact that our sequence contains elemenents,
  # which can be treated as vectors of size 1
  out, hidden = lstm(elem.view(1, 1, 1), hidden)
  print(f'i={i} out={out.detach()}')
print(f'Final hidden state={hidden[0].detach()} cell state={hidden[1].detach()}')
# Out:
# i=0 out=tensor([[[-0.0675,  0.1179,  0.1081,  0.0414, -0.0341]]])
# i=1 out=tensor([[[-0.1067,  0.1726,  0.1400,  0.0902, -0.0596]]])
# i=2 out=tensor([[[-0.1148,  0.1885,  0.1956,  0.0974, -0.0840]]])
# i=3 out=tensor([[[-0.1270,  0.2031,  0.1495,  0.1249, -0.0860]]])
# i=4 out=tensor([[[-0.1281,  0.2019,  0.1810,  0.1475, -0.1027]]])
# i=5 out=tensor([[[-0.1274,  0.2060,  0.0798,  0.1330, -0.0860]]])
# i=6 out=tensor([[[-0.1318,  0.2039,  0.0997,  0.1772, -0.1011]]])
# i=7 out=tensor([[[-0.1145,  0.2008, -0.0431,  0.1051, -0.0717]]])
# i=8 out=tensor([[[-0.1289,  0.1989,  0.0515,  0.1944, -0.1030]]])
# i=9 out=tensor([[[-0.1329,  0.1920,  0.0686,  0.1772, -0.0988]]])
# Final hidden state=tensor([[[-0.1329,  0.1920,  0.0686,  0.1772, -0.0988]]]) cell state=tensor([[[-0.2590,  0.4080,  0.1307,  0.4329, -0.2895]]])

# %% [markdown]
# ## To implement
#
# Process the whole sequence all at once by calling `lstm` only once and check that the output is exactly the same as above (remember to initialize the hidden state the same way).

# %%
# #########################################################
#                    To implement
# #########################################################

x = torch.tensor(sequence)
out, hidden = lstm(x.view(-1, 1, 1))
print(out)
print(hidden)
# Out:
# tensor([[[-0.0675,  0.1179,  0.1081,  0.0414, -0.0341]],
#
#         [[-0.1067,  0.1726,  0.1400,  0.0902, -0.0596]],
#
#         [[-0.1148,  0.1885,  0.1956,  0.0974, -0.0840]],
#
#         [[-0.1270,  0.2031,  0.1495,  0.1249, -0.0860]],
#
#         [[-0.1281,  0.2019,  0.1810,  0.1475, -0.1027]],
#
#         [[-0.1274,  0.2060,  0.0798,  0.1330, -0.0860]],
#
#         [[-0.1318,  0.2039,  0.0997,  0.1772, -0.1011]],
#
#         [[-0.1145,  0.2008, -0.0431,  0.1051, -0.0717]],
#
#         [[-0.1289,  0.1989,  0.0515,  0.1944, -0.1030]],
#
#         [[-0.1329,  0.1920,  0.0686,  0.1772, -0.0988]]],
#        grad_fn=<StackBackward0>)
# (tensor([[[-0.1329,  0.1920,  0.0686,  0.1772, -0.0988]]],
#        grad_fn=<StackBackward0>), tensor([[[-0.2590,  0.4080,  0.1307,  0.4329, -0.2895]]],
#        grad_fn=<StackBackward0>))

# %% [markdown]
# ## Training a model
#
# Below we define a very simple model, which is a single layer of LSTM, where the output in each time step is processed by relu followed by a single fully connected layer, the output of which is a single number. We are going
# to use the number generated after reading the last element of the sequence,
# which will serve as the logit for our classification problem.

# %%
class Model(nn.Module):

    def __init__(self, hidden_dim):
        super(Model, self).__init__()
        self.hidden_dim = hidden_dim
        self.lstm = nn.LSTM(1, self.hidden_dim)
        self.hidden2label = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        sequence_len = x.shape[0]
        logits = self.hidden2label(F.relu(out[-1].view(-1)))
        return logits

# %% [markdown]
# Below is a training loop, where we only train on the two hardest examples.

# %%
SEQUENCE_LEN = 10

# Pairs of (sequence, label)
HARD_EXAMPLES = [([0.]+(SEQUENCE_LEN-1)*[1.], 0),
                 (SEQUENCE_LEN*[1.], 1)]


def eval_on_hard_examples(model, eval_examples=HARD_EXAMPLES):
    with torch.no_grad():
        logits = []
        for sequence in eval_examples:
            input = torch.tensor(sequence[0]).view(-1, 1, 1)
            logit = model(input)
            logits.append(logit.detach())
        print(f'Logits for hard examples={logits}')


def train_model(hidden_dim, lr, num_steps=10000, eval_examples=HARD_EXAMPLES):
    model = Model(hidden_dim=hidden_dim)
    loss_function = nn.BCEWithLogitsLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.99)

    for step in range(num_steps):  
        if step % 100 == 0:
            eval_on_hard_examples(model, eval_examples)

        for sequence, label in HARD_EXAMPLES:
            model.zero_grad()
            logit = model(torch.tensor(sequence).view(-1, 1, 1))  
            
            loss = loss_function(logit.view(-1), torch.tensor([label], dtype=torch.float32))
            loss.backward()

            optimizer.step()  
    return model

# %%
model = train_model(hidden_dim=20, lr=0.01, num_steps=10000)
# Out:
# Logits for hard examples=[tensor([0.0622]), tensor([0.0622])]
# Logits for hard examples=[tensor([0.0105]), tensor([0.0105])]
# Logits for hard examples=[tensor([-0.0090]), tensor([-0.0089])]
# Logits for hard examples=[tensor([0.0025]), tensor([0.0026])]
# Logits for hard examples=[tensor([0.0021]), tensor([0.0023])]
# Logits for hard examples=[tensor([0.0009]), tensor([0.0014])]
# Logits for hard examples=[tensor([0.0017]), tensor([0.0029])]
# Logits for hard examples=[tensor([-0.0097]), tensor([-0.0013])]
# Logits for hard examples=[tensor([-6.0727]), tensor([7.0062])]
# Logits for hard examples=[tensor([-10.4158]), tensor([11.3746])]
# Logits for hard examples=[tensor([-11.0316]), tensor([11.9770])]
# Logits for hard examples=[tensor([-11.1215]), tensor([12.0609])]
# Logits for hard examples=[tensor([-11.1400]), tensor([12.0749])]
# Logits for hard examples=[tensor([-11.1488]), tensor([12.0796])]
# Logits for hard examples=[tensor([-11.1562]), tensor([12.0829])]
# Logits for hard examples=[tensor([-11.1635]), tensor([12.0861])]
# Logits for hard examples=[tensor([-11.1707]), tensor([12.0893])]
# Logits for hard examples=[tensor([-11.1778]), tensor([12.0924])]
# Logits for hard examples=[tensor([-11.1849]), tensor([12.0956])]
# Logits for hard examples=[tensor([-11.1919]), tensor([12.0988])]
# Logits for hard examples=[tensor([-11.1989]), tensor([12.1020])]
# Logits for hard examples=[tensor([-11.2058]), tensor([12.1052])]
# Logits for hard examples=[tensor([-11.2126]), tensor([12.1083])]
# Logits for hard examples=[tensor([-11.2194]), tensor([12.1115])]
# Logits for hard examples=[tensor([-11.2262]), tensor([12.1147])]
# Logits for hard examples=[tensor([-11.2330]), tensor([12.1179])]
# Logits for hard examples=[tensor([-11.2397]), tensor([12.1211])]
# Logits for hard examples=[tensor([-11.2464]), tensor([12.1243])]
# Logits for hard examples=[tensor([-11.2530]), tensor([12.1275])]
# Logits for hard examples=[tensor([-11.2596]), tensor([12.1306])]
# Logits for hard examples=[tensor([-11.2661]), tensor([12.1338])]
# Logits for hard examples=[tensor([-11.2726]), tensor([12.1370])]
# Logits for hard examples=[tensor([-11.2790]), tensor([12.1401])]
# Logits for hard examples=[tensor([-11.2854]), tensor([12.1433])]
# Logits for hard examples=[tensor([-11.2918]), tensor([12.1465])]
# Logits for hard examples=[tensor([-11.2981]), tensor([12.1497])]
# Logits for hard examples=[tensor([-11.3044]), tensor([12.1527])]
# Logits for hard examples=[tensor([-11.3106]), tensor([12.1557])]
# Logits for hard examples=[tensor([-11.3169]), tensor([12.1588])]
# Logits for hard examples=[tensor([-11.3231]), tensor([12.1619])]
# Logits for hard examples=[tensor([-11.3293]), tensor([12.1649])]
# Logits for hard examples=[tensor([-11.3354]), tensor([12.1680])]
# Logits for hard examples=[tensor([-11.3415]), tensor([12.1709])]
# Logits for hard examples=[tensor([-11.3475]), tensor([12.1737])]
# Logits for hard examples=[tensor([-11.3534]), tensor([12.1764])]
# Logits for hard examples=[tensor([-11.3594]), tensor([12.1792])]
# Logits for hard examples=[tensor([-11.3653]), tensor([12.1820])]
# Logits for hard examples=[tensor([-11.3712]), tensor([12.1847])]
# Logits for hard examples=[tensor([-11.3770]), tensor([12.1875])]
# Logits for hard examples=[tensor([-11.3828]), tensor([12.1903])]
# Logits for hard examples=[tensor([-11.3886]), tensor([12.1931])]
# Logits for hard examples=[tensor([-11.3944]), tensor([12.1958])]
# Logits for hard examples=[tensor([-11.4002]), tensor([12.1985])]
# Logits for hard examples=[tensor([-11.4059]), tensor([12.2013])]
# Logits for hard examples=[tensor([-11.4116]), tensor([12.2040])]
# Logits for hard examples=[tensor([-11.4173]), tensor([12.2068])]
# Logits for hard examples=[tensor([-11.4229]), tensor([12.2095])]
# Logits for hard examples=[tensor([-11.4284]), tensor([12.2123])]
# Logits for hard examples=[tensor([-11.4339]), tensor([12.2151])]
# Logits for hard examples=[tensor([-11.4394]), tensor([12.2178])]
# Logits for hard examples=[tensor([-11.4448]), tensor([12.2205])]
# Logits for hard examples=[tensor([-11.4503]), tensor([12.2233])]
# Logits for hard examples=[tensor([-11.4557]), tensor([12.2260])]
# Logits for hard examples=[tensor([-11.4611]), tensor([12.2287])]
# Logits for hard examples=[tensor([-11.4664]), tensor([12.2315])]
# Logits for hard examples=[tensor([-11.4718]), tensor([12.2342])]
# Logits for hard examples=[tensor([-11.4771]), tensor([12.2370])]
# Logits for hard examples=[tensor([-11.4824]), tensor([12.2397])]
# Logits for hard examples=[tensor([-11.4876]), tensor([12.2425])]
# Logits for hard examples=[tensor([-11.4929]), tensor([12.2452])]
# Logits for hard examples=[tensor([-11.4981]), tensor([12.2479])]
# Logits for hard examples=[tensor([-11.5033]), tensor([12.2506])]
# Logits for hard examples=[tensor([-11.5085]), tensor([12.2533])]
# Logits for hard examples=[tensor([-11.5136]), tensor([12.2560])]
# Logits for hard examples=[tensor([-11.5187]), tensor([12.2587])]
# Logits for hard examples=[tensor([-11.5238]), tensor([12.2614])]
# Logits for hard examples=[tensor([-11.5288]), tensor([12.2642])]
# Logits for hard examples=[tensor([-11.5338]), tensor([12.2669])]
# Logits for hard examples=[tensor([-11.5387]), tensor([12.2696])]
# Logits for hard examples=[tensor([-11.5437]), tensor([12.2723])]
# Logits for hard examples=[tensor([-11.5486]), tensor([12.2749])]
# Logits for hard examples=[tensor([-11.5535]), tensor([12.2776])]
# Logits for hard examples=[tensor([-11.5584]), tensor([12.2803])]
# Logits for hard examples=[tensor([-11.5633]), tensor([12.2830])]
# Logits for hard examples=[tensor([-11.5681]), tensor([12.2857])]
# Logits for hard examples=[tensor([-11.5730]), tensor([12.2884])]
# Logits for hard examples=[tensor([-11.5778]), tensor([12.2911])]
# Logits for hard examples=[tensor([-11.5826]), tensor([12.2938])]
# Logits for hard examples=[tensor([-11.5874]), tensor([12.2965])]
# Logits for hard examples=[tensor([-11.5921]), tensor([12.2991])]
# Logits for hard examples=[tensor([-11.5969]), tensor([12.3018])]
# Logits for hard examples=[tensor([-11.6016]), tensor([12.3044])]
# Logits for hard examples=[tensor([-11.6063]), tensor([12.3071])]
# Logits for hard examples=[tensor([-11.6110]), tensor([12.3098])]
# Logits for hard examples=[tensor([-11.6156]), tensor([12.3124])]
# Logits for hard examples=[tensor([-11.6202]), tensor([12.3151])]
# Logits for hard examples=[tensor([-11.6247]), tensor([12.3178])]
# Logits for hard examples=[tensor([-11.6293]), tensor([12.3205])]
# Logits for hard examples=[tensor([-11.6338]), tensor([12.3231])]
# Logits for hard examples=[tensor([-11.6383]), tensor([12.3258])]

# %% [markdown]
# ## To implement
#
# 1. Check for what values of `SEQUENCE_LEN` the model is able to discriminate betweeh the two hard examples (after training).
# 2. Instead of training on `HARD_EXAMPLES` only, modify the training loop to train on sequences where zero may be in any position of the sequence (so any valid sequence of `Type 0`, not just the hardest one). After modifying the training loop check for what values of `SEQUENCE_LEN` you can train the model successfully.
# 3. Replace LSTM by a classic RNN and check for what values of `SEQUENCE_LEN` you can train the model successfully.
# 4. Write a proper curricullum learning loop, where in a loop you consider longer and longer sequences, where expansion of the sequence length happens only after the model is trained successfully on the current length.
#
# Note that for steps 2-4 you may need to change the value of `num_steps`.

# %%
# Pairs of (sequence, label)
for seq_length in range(1, 100):
  examples = [([0.]+(seq_length-1)*[1.], 0),
                  (seq_length*[1.], 1)]

  eval_on_hard_examples(model, examples)
# Out:
# Logits for hard examples=[tensor([-6.5027]), tensor([0.0296])]
# Logits for hard examples=[tensor([-9.5344]), tensor([4.1725])]
# Logits for hard examples=[tensor([-10.9729]), tensor([9.3146])]
# Logits for hard examples=[tensor([-11.3375]), tensor([11.4541])]
# Logits for hard examples=[tensor([-11.4912]), tensor([12.0216])]
# Logits for hard examples=[tensor([-11.5648]), tensor([12.2063])]
# Logits for hard examples=[tensor([-11.6031]), tensor([12.2756])]
# Logits for hard examples=[tensor([-11.6240]), tensor([12.3060])]
# Logits for hard examples=[tensor([-11.6359]), tensor([12.3205])]
# Logits for hard examples=[tensor([-11.6428]), tensor([12.3284])]
# Logits for hard examples=[tensor([-11.6468]), tensor([12.3329])]
# Logits for hard examples=[tensor([-11.6492]), tensor([12.3359])]
# Logits for hard examples=[tensor([-11.6507]), tensor([12.3378])]
# Logits for hard examples=[tensor([-11.6516]), tensor([12.3392])]
# Logits for hard examples=[tensor([-11.6522]), tensor([12.3401])]
# Logits for hard examples=[tensor([-11.6525]), tensor([12.3408])]
# Logits for hard examples=[tensor([-11.6527]), tensor([12.3413])]
# Logits for hard examples=[tensor([-11.6529]), tensor([12.3416])]
# Logits for hard examples=[tensor([-11.6530]), tensor([12.3419])]
# Logits for hard examples=[tensor([-11.6531]), tensor([12.3421])]
# Logits for hard examples=[tensor([-11.6531]), tensor([12.3422])]
# Logits for hard examples=[tensor([-11.6531]), tensor([12.3423])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3424])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3425])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3425])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3426])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3426])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3426])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3426])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3426])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3426])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6532]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]
# Logits for hard examples=[tensor([-11.6533]), tensor([12.3427])]

# %%
def train_model(hidden_dim, lr, num_steps=10000, eval_examples=HARD_EXAMPLES):
    model = Model(hidden_dim=hidden_dim)
    loss_function = nn.BCEWithLogitsLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.99)

    for step in range(num_steps):  
        if step % 100 == 0:
            eval_on_hard_examples(model, eval_examples)

        for sequence, label in HARD_EXAMPLES:
            model.zero_grad()
            logit = model(torch.tensor(sequence).view(-1, 1, 1))  
            
            loss = loss_function(logit.view(-1), torch.tensor([label], dtype=torch.float32))
            loss.backward()

            optimizer.step()  
    return model
